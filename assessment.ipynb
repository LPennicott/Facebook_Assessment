# %%
import pandas as pd
import numpy as np
import datetime

# %%
attrition_df = pd.read_csv('Take home assessment Doc_ Sample_Employee_Termination_Data.csv',
                           parse_dates=['recorddate_key', 'orighiredate_key', 'terminationdate_key'])

# %%
attrition_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           49653 non-null  int64
#  1   recorddate_key       49653 non-null  datetime64[ns]
#  2   birthdate_key        49653 non-null  object
#  3   orighiredate_key     49653 non-null  datetime64[ns]
#  4   terminationdate_key  49653 non-null  datetime64[ns]
#  5   age                  49653 non-null  int64
#  6   length_of_service    49653 non-null  int64
#  7   city_name            49653 non-null  object
#  8   department_name      49653 non-null  object
#  9   job_title            49653 non-null  object
#  10  store_name           49653 non-null  int64
#  11  gender_short         49653 non-null  object
#  12  gender_full          49653 non-null  object
#  13  termreason_desc      49653 non-null  object
#  14  termtype_desc        49653 non-null  object
#  15  STATUS_YEAR          49653 non-null  int64
#  16  STATUS               49653 non-null  object
#  17  BUSINESS_UNIT        49653 non-null  object
# dtypes: datetime64[ns](3), int64(5), object(10)
# memory usage: 6.8+ MB

# %%
attrition_df.head()
# Out:
#    EmployeeID recorddate_key birthdate_key orighiredate_key  \
# 0        1318     2006-12-31        1/3/54       1989-08-28
# 1        1318     2007-12-31        1/3/54       1989-08-28
# 2        1318     2008-12-31        1/3/54       1989-08-28
# 3        1318     2009-12-31        1/3/54       1989-08-28
# 4        1318     2010-12-31        1/3/54       1989-08-28
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0          2000-01-01   52                 17  Vancouver       Executive
# 1          2000-01-01   53                 18  Vancouver       Executive
# 2          2000-01-01   54                 19  Vancouver       Executive
# 3          2000-01-01   55                 20  Vancouver       Executive
# 4          2000-01-01   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
# 3       CEO          35            M        Male  Not Applicable
# 4       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1  Not Applicable         2007  ACTIVE    HEADOFFICE
# 2  Not Applicable         2008  ACTIVE    HEADOFFICE
# 3  Not Applicable         2009  ACTIVE    HEADOFFICE
# 4  Not Applicable         2010  ACTIVE    HEADOFFICE

# %%
# function to fix birthdate_key series
def fix_date(x: pd.Series) -> datetime.date:
    month = int(x.split('/')[0])
    day = int(x.split('/')[1])
    year = int('19' + x.split('/')[2])
    return datetime.date(year, month, day)

# %%
attrition_df['birthdate'] = attrition_df['birthdate_key'].apply(fix_date)
attrition_df['birthdate']
# Out:
# 0        1954-01-03
# 1        1954-01-03
# 2        1954-01-03
# 3        1954-01-03
# 4        1954-01-03
#             ...
# 49648    1994-05-28
# 49649    1994-06-13
# 49650    1994-07-18
# 49651    1994-09-02
# 49652    1994-11-28
# Name: birthdate, Length: 49653, dtype: object

# %%
# Dropping unneeded column
attrition_df = attrition_df.drop(columns=['birthdate_key'])

# %%
# Grouping columns by EmployeeID to get latest relevant row
att_group = attrition_df.groupby('EmployeeID')

# %%
attrition_df_cleaned = att_group.apply(lambda x: x[x['length_of_service'] == x['length_of_service'].max()])

# %%
attrition_df_cleaned['job_title_general'] = np.nan
attrition_df_cleaned.loc[attrition_df_cleaned['job_title'].str.contains('VP'), 'job_title_general'] = 'VP'
attrition_df_cleaned.loc[attrition_df_cleaned['job_title'].str.contains('Manager'), 'job_title_general'] = 'Manager'
attrition_df_cleaned.loc[attrition_df_cleaned['job_title'].str.contains('Director'), 'job_title_general'] = 'Director'
attrition_df_cleaned.loc[attrition_df_cleaned['job_title'].str.contains('Analyst'), 'job_title_general'] = 'Analyst'

# %%
# Confirming change
attrition_df_cleaned.loc[attrition_df_cleaned['job_title_general'].isin(['VP', 'Manager', 'Director', 'Analyst'])]
# Out:
#                   EmployeeID recorddate_key orighiredate_key  \
# EmployeeID
# 1319       19           1319     2015-12-31       1989-08-28
# 1321       39           1321     2015-12-31       1989-08-28
# 1322       49           1322     2015-12-31       1989-08-31
# 1323       59           1323     2015-12-31       1989-08-31
# 1329       89           1329     2015-12-31       1989-09-08
# ...                      ...            ...              ...
# 3850       48758        3850     2014-12-01       1996-10-21
# 3970       48781        3970     2014-12-01       1997-02-21
# 3994       48787        3994     2014-12-01       1997-03-16
# 4710       49028        4710     2014-12-01       1999-05-10
# 5007       49152        5007     2014-12-01       2000-03-09
#
#                  terminationdate_key  age  length_of_service  \
# EmployeeID
# 1319       19             2000-01-01   58                 26
# 1321       39             2000-01-01   56                 26
# 1322       49             2000-01-01   57                 26
# 1323       59             2000-01-01   53                 26
# 1329       89             2000-01-01   48                 26
# ...                              ...  ...                ...
# 3850       48758          2014-12-30   52                 18
# 3970       48781          2014-12-30   51                 17
# 3994       48787          2014-12-30   51                 17
# 4710       49028          2014-12-30   47                 15
# 5007       49152          2014-12-30   46                 14
#
#                          city_name   department_name  \
# EmployeeID
# 1319       19            Vancouver         Executive
# 1321       39            Vancouver         Executive
# 1322       49            Vancouver         Executive
# 1323       59            Vancouver         Executive
# 1329       89              Terrace  Store Management
# ...                            ...               ...
# 3850       48758       Fort Nelson  Customer Service
# 3970       48781  New Westminister   Processed Foods
# 3994       48787       Grand Forks            Bakery
# 4710       49028       Grand Forks   Processed Foods
# 5007       49152       Grand Forks  Customer Service
#
#                                   job_title  store_name gender_short  \
# EmployeeID
# 1319       19                     VP Stores          35            F
# 1321       39            VP Human Resources          35            M
# 1322       49                    VP Finance          35            M
# 1323       59     Exec Assistant, VP Stores          35            M
# 1329       89                 Store Manager          32            F
# ...                                     ...         ...          ...
# 3850       48758   Customer Service Manager          11            M
# 3970       48781    Processed Foods Manager          20            M
# 3994       48787             Bakery Manager          13            F
# 4710       49028    Processed Foods Manager          13            F
# 5007       49152   Customer Service Manager          13            M
#
#                  gender_full termreason_desc   termtype_desc  STATUS_YEAR  \
# EmployeeID
# 1319       19         Female  Not Applicable  Not Applicable         2015
# 1321       39           Male  Not Applicable  Not Applicable         2015
# 1322       49           Male  Not Applicable  Not Applicable         2015
# 1323       59           Male  Not Applicable  Not Applicable         2015
# 1329       89         Female  Not Applicable  Not Applicable         2015
# ...                      ...             ...             ...          ...
# 3850       48758        Male          Layoff     Involuntary         2014
# 3970       48781        Male          Layoff     Involuntary         2014
# 3994       48787      Female          Layoff     Involuntary         2014
# 4710       49028      Female          Layoff     Involuntary         2014
# 5007       49152        Male          Layoff     Involuntary         2014
#
#                       STATUS BUSINESS_UNIT   birthdate job_title_general
# EmployeeID
# 1319       19         ACTIVE    HEADOFFICE  1957-01-03                VP
# 1321       39         ACTIVE    HEADOFFICE  1959-01-02                VP
# 1322       49         ACTIVE    HEADOFFICE  1958-01-09                VP
# 1323       59         ACTIVE    HEADOFFICE  1962-01-09                VP
# 1329       89         ACTIVE        STORES  1967-01-23           Manager
# ...                      ...           ...         ...               ...
# 3850       48758  TERMINATED        STORES  1962-07-18           Manager
# 3970       48781  TERMINATED        STORES  1963-03-07           Manager
# 3994       48787  TERMINATED        STORES  1963-04-19           Manager
# 4710       49028  TERMINATED        STORES  1967-05-15           Manager
# 5007       49152  TERMINATED        STORES  1968-12-11           Manager
#
# [304 rows x 19 columns]

# %%
# Reordering columns
attrition_df_final = attrition_df_cleaned[['EmployeeID',
 'recorddate_key',
 'orighiredate_key',
 'birthdate',
 'terminationdate_key',
 'age',
 'length_of_service',
 'city_name',
 'department_name',
 'job_title_general',
 'store_name',
 'gender_short',
 'gender_full',
 'termreason_desc',
 'termtype_desc',
 'STATUS_YEAR',
 'STATUS',
 'BUSINESS_UNIT',
]]

# %%
# exporting for visualization
attrition_df_final.to_csv('Sample_Employee_Termination_Data_cleaned.csv', index=False)
